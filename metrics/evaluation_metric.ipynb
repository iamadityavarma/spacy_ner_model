# %%
pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.8.7-cp313-cp313-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.13-cp313-cp313-win_amd64.whl.metadata (2.2 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.11-cp313-cp313-win_amd64.whl.metadata (8.8 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.10-cp313-cp313-win_amd64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.6-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.1-cp313-cp313-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Using cached typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting numpy>=1.19.0 (from spacy)
#   Downloading numpy-2.3.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting requests<3.0.0,>=2.13.0 (from spacy)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting jinja2 (from spacy)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting setuptools (from spacy)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\adity\.conda\envs\myenv\lib\site-packages (from spacy) (25.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Using cached langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Using cached language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\adity\.conda\envs\myenv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.1)
# Collecting typing-inspection>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading certifi-2025.7.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.0-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\adity\.conda\envs\myenv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Collecting click>=8.0.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Using cached cloudpathlib-0.21.1-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Using cached smart_open-7.3.0.post1-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy)
#   Downloading wrapt-1.17.2-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.1-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\adity\.conda\envs\myenv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy)
#   Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl.metadata (4.1 kB)
# Downloading spacy-3.8.7-cp313-cp313-win_amd64.whl (13.9 MB)
#    ---------------------------------------- 0.0/13.9 MB ? eta -:--:--
#    -------------------- ------------------- 7.1/13.9 MB 38.7 MB/s eta 0:00:01
#    ---------------------------------------  13.9/13.9 MB 37.1 MB/s eta 0:00:01
#    ---------------------------------------- 13.9/13.9 MB 27.4 MB/s eta 0:00:00
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.11-cp313-cp313-win_amd64.whl (39 kB)
# Using cached langcodes-3.5.0-py3-none-any.whl (182 kB)
# Downloading murmurhash-1.0.13-cp313-cp313-win_amd64.whl (24 kB)
# Downloading preshed-3.0.10-cp313-cp313-win_amd64.whl (115 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 21.2 MB/s eta 0:00:00
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl (105 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.1-cp313-cp313-win_amd64.whl (630 kB)
#    ---------------------------------------- 0.0/630.6 kB ? eta -:--:--
#    --------------------------------------- 630.6/630.6 kB 17.0 MB/s eta 0:00:00
# Downloading thinc-8.3.6-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 36.3 MB/s eta 0:00:00
# Downloading blis-1.3.0-cp313-cp313-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ----------------------------------- ---- 5.5/6.3 MB 26.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 19.5 MB/s eta 0:00:00
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading numpy-2.3.1-cp313-cp313-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    --------------------------- ------------ 8.7/12.7 MB 40.2 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.7 MB 38.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 24.5 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typer-0.16.0-py3-none-any.whl (46 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# Using cached cloudpathlib-0.21.1-py3-none-any.whl (52 kB)
# Using cached smart_open-7.3.0.post1-py3-none-any.whl (61 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2025.7.14-py3-none-any.whl (162 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Using cached language_data-1.3.0-py3-none-any.whl (5.4 MB)
# Downloading marisa_trie-1.2.1-cp313-cp313-win_amd64.whl (149 kB)
# Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl (15 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Downloading wrapt-1.17.2-cp313-cp313-win_amd64.whl (38 kB)
# Installing collected packages: cymem, wrapt, wasabi, urllib3, typing-inspection, tqdm, spacy-loggers, spacy-legacy, shellingham, setuptools, pydantic-core, numpy, murmurhash, mdurl, MarkupSafe, idna, cloudpathlib, click, charset_normalizer, certifi, catalogue, annotated-types, srsly, smart-open, requests, pydantic, preshed, markdown-it-py, marisa-trie, jinja2, blis, rich, language-data, confection, typer, thinc, langcodes, weasel, spacy
#
#    - --------------------------------------  1/39 [wrapt]
#    -- -------------------------------------  2/39 [wasabi]
#    -- -------------------------------------  2/39 [wasabi]
#    --- ------------------------------------  3/39 [urllib3]
#    --- ------------------------------------  3/39 [urllib3]
#    --- ------------------------------------  3/39 [urllib3]
#    --- ------------------------------------  3/39 [urllib3]
#    --- ------------------------------------  3/39 [urllib3]
#    ----- ----------------------------------  5/39 [tqdm]
#    ----- ----------------------------------  5/39 [tqdm]
#    ----- ----------------------------------  5/39 [tqdm]
#    ----- ----------------------------------  5/39 [tqdm]
#    ----- ----------------------------------  5/39 [tqdm]
#    ----- ----------------------------------  5/39 [tqdm]
#    ------ ---------------------------------  6/39 [spacy-loggers]
#    ------- --------------------------------  7/39 [spacy-legacy]
#    -------- -------------------------------  8/39 [shellingham]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    --------- ------------------------------  9/39 [setuptools]
#    ---------- ----------------------------- 10/39 [pydantic-core]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ----------- ---------------------------- 11/39 [numpy]
#    ------------ --------------------------- 12/39 [murmurhash]
#    ------------- -------------------------- 13/39 [mdurl]
#    --------------- ------------------------ 15/39 [idna]
#    ---------------- ----------------------- 16/39 [cloudpathlib]
#    ---------------- ----------------------- 16/39 [cloudpathlib]
#    ---------------- ----------------------- 16/39 [cloudpathlib]
#    ---------------- ----------------------- 16/39 [cloudpathlib]
#    ----------------- ---------------------- 17/39 [click]
#    ----------------- ---------------------- 17/39 [click]
#    ----------------- ---------------------- 17/39 [click]
#    ------------------ --------------------- 18/39 [charset_normalizer]
#    ------------------ --------------------- 18/39 [charset_normalizer]
#    ------------------- -------------------- 19/39 [certifi]
#    -------------------- ------------------- 20/39 [catalogue]
#    ---------------------- ----------------- 22/39 [srsly]
#    ---------------------- ----------------- 22/39 [srsly]
#    ---------------------- ----------------- 22/39 [srsly]
#    ---------------------- ----------------- 22/39 [srsly]
#    ---------------------- ----------------- 22/39 [srsly]
#    ---------------------- ----------------- 22/39 [srsly]
#    ---------------------- ----------------- 22/39 [srsly]
#    ---------------------- ----------------- 22/39 [srsly]
#    ---------------------- ----------------- 22/39 [srsly]
#    ---------------------- ----------------- 22/39 [srsly]
#    ----------------------- ---------------- 23/39 [smart-open]
#    ----------------------- ---------------- 23/39 [smart-open]
#    ----------------------- ---------------- 23/39 [smart-open]
#    ------------------------ --------------- 24/39 [requests]
#    ------------------------ --------------- 24/39 [requests]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    ------------------------- -------------- 25/39 [pydantic]
#    -------------------------- ------------- 26/39 [preshed]
#    --------------------------- ------------ 27/39 [markdown-it-py]
#    --------------------------- ------------ 27/39 [markdown-it-py]
#    --------------------------- ------------ 27/39 [markdown-it-py]
#    --------------------------- ------------ 27/39 [markdown-it-py]
#    --------------------------- ------------ 27/39 [markdown-it-py]
#    --------------------------- ------------ 27/39 [markdown-it-py]
#    --------------------------- ------------ 27/39 [markdown-it-py]
#    --------------------------- ------------ 27/39 [markdown-it-py]
#    --------------------------- ------------ 27/39 [markdown-it-py]
#    --------------------------- ------------ 27/39 [markdown-it-py]
#    ----------------------------- ---------- 29/39 [jinja2]
#    ----------------------------- ---------- 29/39 [jinja2]
#    ----------------------------- ---------- 29/39 [jinja2]
#    ----------------------------- ---------- 29/39 [jinja2]
#    ------------------------------ --------- 30/39 [blis]
#    ------------------------------- -------- 31/39 [rich]
#    ------------------------------- -------- 31/39 [rich]
#    ------------------------------- -------- 31/39 [rich]
#    ------------------------------- -------- 31/39 [rich]
#    ------------------------------- -------- 31/39 [rich]
#    ------------------------------- -------- 31/39 [rich]
#    ------------------------------- -------- 31/39 [rich]
#    ------------------------------- -------- 31/39 [rich]
#    ------------------------------- -------- 31/39 [rich]
#    ------------------------------- -------- 31/39 [rich]
#    -------------------------------- ------- 32/39 [language-data]
#    -------------------------------- ------- 32/39 [language-data]
#    -------------------------------- ------- 32/39 [language-data]
#    -------------------------------- ------- 32/39 [language-data]
#    -------------------------------- ------- 32/39 [language-data]
#    -------------------------------- ------- 32/39 [language-data]
#    -------------------------------- ------- 32/39 [language-data]
#    -------------------------------- ------- 32/39 [language-data]
#    -------------------------------- ------- 32/39 [language-data]
#    -------------------------------- ------- 32/39 [language-data]
#    --------------------------------- ------ 33/39 [confection]
#    ---------------------------------- ----- 34/39 [typer]
#    ---------------------------------- ----- 34/39 [typer]
#    ---------------------------------- ----- 34/39 [typer]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ----------------------------------- ---- 35/39 [thinc]
#    ------------------------------------ --- 36/39 [langcodes]
#    ------------------------------------ --- 36/39 [langcodes]
#    ------------------------------------ --- 36/39 [langcodes]
#    ------------------------------------- -- 37/39 [weasel]
#    ------------------------------------- -- 37/39 [weasel]
#    ------------------------------------- -- 37/39 [weasel]
#    ------------------------------------- -- 37/39 [weasel]
#    ------------------------------------- -- 37/39 [weasel]
#    ------------------------------------- -- 37/39 [weasel]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    -------------------------------------- - 38/39 [spacy]
#    ---------------------------------------- 39/39 [spacy]
#
# Successfully installed MarkupSafe-3.0.2 annotated-types-0.7.0 blis-1.3.0 catalogue-2.0.10 certifi-2025.7.14 charset_normalizer-3.4.2 click-8.2.1 cloudpathlib-0.21.1 confection-0.1.5 cymem-2.0.11 idna-3.10 jinja2-3.1.6 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.2.1 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.13 numpy-2.3.1 preshed-3.0.10 pydantic-2.11.7 pydantic-core-2.33.2 requests-2.32.4 rich-14.0.0 setuptools-80.9.0 shellingham-1.5.4 smart-open-7.3.0.post1 spacy-3.8.7 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.1 thinc-8.3.6 tqdm-4.67.1 typer-0.16.0 typing-inspection-0.4.1 urllib3-2.5.0 wasabi-1.1.3 weasel-0.4.1 wrapt-1.17.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
from spacy.scorer import Scorer
from spacy.training.example import Example
from spacy.tokens import DocBin
import os

try:
    # Load model and dev data
    model_path = r"C:\Aditya\folders\Study_Vault\Proxzar\Capstone\models"
    test_data_path = "training/test.spacy"
    
    # Check if paths exist
    if not os.path.exists(model_path):
        raise FileNotFoundError(f"Model not found at: {model_path}")
    if not os.path.exists(test_data_path):
        raise FileNotFoundError(f"Test data not found at: {test_data_path}")
    
    print("Loading model...")
    nlp = spacy.load(model_path)
    
    print("Loading test data...")
    doc_bin = DocBin().from_disk(test_data_path)
    docs = list(doc_bin.get_docs(nlp.vocab))
    
    print(f"Processing {len(docs)} test documents...")
    
    # Convert to Example objects
    examples = []
    for i, doc in enumerate(docs):
        try:
            predicted = nlp(doc.text)
            examples.append(Example(predicted=predicted, reference=doc))
        except Exception as e:
            print(f"Error processing document {i}: {e}")
            continue
    
    print(f"Created {len(examples)} examples for evaluation")
    
    # Run evaluation
    scorer = Scorer()
    results = scorer.score(examples)
    
    # Display main scores
    print("\n=== OVERALL SCORES ===")
    print(f"F1: {results['ents_f']:.4f}")
    print(f"Precision: {results['ents_p']:.4f}")
    print(f"Recall: {results['ents_r']:.4f}")
    
    # Per-label breakdown
    print("\n=== PER-LABEL SCORES ===")
    for label, scores in results["ents_per_type"].items():
        print(f"{label:12}: P={scores['p']:.4f}, R={scores['r']:.4f}, F1={scores['f']:.4f}")
    
    # Additional useful metrics
    if "token_acc" in results:
        print(f"\nToken Accuracy: {results['token_acc']:.4f}")
    
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: Test data not found at: training/test.spacy
